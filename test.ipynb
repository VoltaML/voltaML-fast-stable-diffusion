# %%
from core.inference.pytorch import PyTorchInferenceModel

# %%
model = PyTorchInferenceModel(model_id="Linaqruf/anything-v3.0", scheduler="euler_a")
# Out:
# Loading model with f16
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# You have passed `None` for safety_checker to disable its functionality in <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'>. Note that this might lead to problems when using <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> and is not recommended.
# ...

# %%
from api.types import Txt2imgJob

# %%
job = Txt2imgJob(
    backend="PyTorch",
    batch_count=1,
    batch_size=1,
    guidance_scale=7,
    height=512,
    id="420",
    prompt="1girl, brown hair, green eyes, colorful, autumn, cumulonimbus clouds, lighting, blue sky, falling leaves, garden",
    negative_prompt="",
    model_path="Linaqruf/anything-v3.0",
    seed=420,
    steps=50,
    width=512,
)

# %%
images = model.generate(job)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
